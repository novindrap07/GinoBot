# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

from rasa_core_sdk import Action
from rasa_core_sdk.events import SlotSet
import logging
logger = logging.getLogger(__name__)
import json
import requests

# %%
class ActionJurusan(Action):
    def name(self):
        return "action_jurusan"
    
    def run(self, dispatcher, tracker, domain):
        dispatcher.utter_template("utter_jurusan")
            
        return [SlotSet("jurusan")]

# %%
class ActionMatkul(Action):
    def name(self):
        return "action_matkul"
    
    def run(self, dispatcher, tracker, domain):
        dispatcher.utter_message(tracker.get_slot("matkul"))
        tracker.get_slot('matkul')
        with open('info_matkul.json') as json_file:  
            data = json.load(json_file)
            for p in data:
                print('Mata Kuliah : ' + p['Mata Kuliah'])
                print('')
        return [SlotSet("matkul")]

# %%
class ActionInfomatkul(Action):
    def name(self):
        return 'action_infomatkul'

    def run(self, dispatcher, tracker, domain):
        info_matkul = [
            {
                "kode mata kuliah": 1700000101, 
                "mata kuliah": "pendidikan kewarganegaraan", 
                "sks": 2, 
                "semester": "ganjil", 
                "informasi mata kuliah": "sebuah ilmu atau studi mengenai tugas dan kewajiban pemerintahan serta hak dan kewajiban seorang warga negara.",
                "topik mata kuliah": "hak dan kewajiban warga negaranya, jati diri atau identitas bangsa dan negara, konstitusi negara.",
                "software": "-",
                "sesi mata kuliah": "08.00 - 09.40",
                "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
                "referensi mata kuliah": "-"
            },
            {
                "kode mata kuliah": 1700000102,
                "mata kuliah": "bahasa indonesia",
                "sks": 2,
                "semester": "ganjil",
                "informasi mata kuliah": "studi mengenai ilmu bahasa yang dimana dapat mendorong mahasiswa menggunakan bahasa yang sesuai dengan kaidah dan norma yang berlaku.",
                "topik mata kuliah": "sejarah bahasa indonesia, komunikasi lisan dan kalimat induktif.",
                "software": "-",
                "sesi mata kuliah": "09.50 - 11.30",
                "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
                "referensi mata kuliah": "-"
            },
            {
                "kode mata kuliah": 1708020303,
                "mata kuliah": "agama",
                "sks": 2,
                "semester": "ganjil",
                "informasi mata kuliah": "studi mengenai ilmu kerohanian dimana dapat membangun keimanan dan ketaqwaan kepada tuhan yang maha esa.",
                "topik mata kuliah": "pengantar rukun iman dan islam, pengabdian masyarakat.",
                "software": "-",
                "sesi mata kuliah": "11.40 - 13.20",
                "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
                "referensi mata kuliah": "-"
            },
            {
                "kode mata kuliah": 1703023402,
                "mata kuliah": "toefl preparation",
                "sks": 2,
                "semester": "ganjil",
                "informasi mata kuliah": "studi tentang ilmu bahasa inggris dan persiapan pada tes toefl.",
                "topik mata kuliah": "spelling, toefl topic, reading,  english conversation.",
                "software": "-",
                "sesi mata kuliah": "13.30 - 15.10",
                "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
                "referensi mata kuliah": "-"
            },
            {
                "kode mata kuliah": 1708030203,
                "mata kuliah": "matematika diskrit",
                "sks": 2,
                "semester": "ganjil",
                "informasi mata kuliah": "studi mengenai dasar – dasar matematika teknologi.",
                "topik mata kuliah": "himpunan, relasi, fungsi dan proposisi, poset, lattice, dan aljabar boolean.",
                "software": "-",
                "sesi mata kuliah": "15.20 - 17.00",
                "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
                "referensi mata kuliah": "-"
             },
             {
                "kode mata kuliah": 1708020203,
                "mata kuliah": "dasar-dasar pemrograman i",
                "sks": 2,
                "semester": "ganjil",
                "informasi mata kuliah": "studi tentang dasar pada pemrograman dan logika pemrograman.",
                "topik mata kuliah": "dasar logika pemrograman, bahasa pemrograman c++",
                "software": "-",
                "sesi mata kuliah": "17.00 - 18.30",
                "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
                "referensi mata kuliah": "https://drive.google.com/open?id=1rkxygthotentcfcnw-toksqfjfo78dlt"
            },
            {
                "kode mata kuliah": 1708020204,
                "mata kuliah": "praktikum dasar - dasar pemrograman i",
                "sks": 1,
                "semester": "ganjil",
                "informasi mata kuliah": "studi tentang dasar pada pemrograman dan logika pemrograman.",
                "topik mata kuliah": "dasar logika pemrograman, bahasa pemrograman c++",
                "software": "dev c++, netbeans, turbo c++ 4.5, microsoft visual studio",
                "sesi mata kuliah": "18.40 - 20.20",
                "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
                "referensi mata kuliah": "https://drive.google.com/open?id=1rkxygthotentcfcnw-toksqfjfo78dlt"
            },
            {
                "kode mata kuliah": 1708030214,
                "mata kuliah": "pengantar teknologi sistem informasi",
                "sks": 2,
                "semester": "ganjil",
                "informasi mata kuliah": "studi mengenai pengantar teknologi sebagai dasar – dasar teknologi.",
                "topik mata kuliah": "dasar software dan hardware, implementasi dalam kehidupan sehari – hari.",
                "software": "-",
                "sesi mata kuliah": "20.30 - 21.30",
                "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
                "referensi mata kuliah": "-"
            },
            {
                "kode mata kuliah": 1708020303,
                "mata kuliah": "analisa proses bisnis",
                "sks": 3,
                "semester": "ganjil",
                "informasi mata kuliah": "studi mengenai struktur dan pendalaman pada proses bisnis.",
                "topik mata kuliah": "proses bisnis, visualisasi data.",
                "software": "-",
                "sesi mata kuliah": "08.00 - 09.40",
                "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
                "referensi mata kuliah": "-"
            },
            {
                "kode mata kuliah": 1708020301,
                "mata kuliah": "sistem aplikasi akuntansi",
                "sks": 2,
                "semester": "genap",
                "informasi mata kuliah": "studi tentang teori dan penggunaan perangkat lunak (software) pada akuntansi.",
                "topik mata kuliah": "teori akuntansi dan aplikasi akuntansi.",
                "software": "-",
                "sesi mata kuliah": "09.50 - 11.30",
                "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
                "referensi mata kuliah": "https://drive.google.com/open?id=1im7kphtjurwzuiwfda2zsr5seouopj_j"
            },
            {
                "kode mata kuliah": 1708020302,
                "mata kuliah": "praktikum sistem aplikasi akuntansi",
                "sks": 1,
                "semester": "genap",
                "informasi mata kuliah": "studi tentang teori dan penggunaan perangkat lunak (software) pada akuntansi.",
                "topik mata kuliah": "dasar – dasar penggunaan aplikasi akuntansi.",
                "software": "myob",
                "sesi mata kuliah": "11.40 - 13.20",
                "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
                "referensi mata kuliah": "https://drive.google.com/open?id=1im7kphtjurwzuiwfda2zsr5seouopj_j"
            },
            {
                "kode mata kuliah": 1708030220,
                "mata kuliah": "statistika dan probabilitas",
                "sks": 2,
                "semester": "genap",
                "informasi mata kuliah": "studi mengenai ilmu statistika dan dasar perhitungan pada penerapan teknologi.",
                "topik mata kuliah": "mean, median, modus",
                "software": "-",
                "sesi mata kuliah": "13.30 - 15.10",
                "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
                "referensi mata kuliah": "https://drive.google.com/open?id=12fscnmv_oopupafp-mqxxv864kr6emx2"
            },
            {
                "kode mata kuliah": 1708020201,
                "mata kuliah": "manajemen umum",
                "sks": 2,
                "semester": "genap",
                "informasi mata kuliah": "studi tentang ilmu manajamen yang penerapannya pada organisasi.",
                "topik mata kuliah": "dasar dan teori manajemen.",
                "software": "-",
                "sesi mata kuliah": "15.20 - 17.00",
                "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
                "referensi mata kuliah": "-"
            },
            {
                "kode mata kuliah": 1708020207,
                "mata kuliah": "struktur data dan algoritma",
                "sks": 4,
                "semester": "genap",
                "informasi mata kuliah": "studi tentang analisa struktur pemrograman dan dasar algoritma pada pemrograman.",
                "topik mata kuliah": "dasar algoritma, stack and queue.",
                "software": "dev c++, turbo c++ 4.5, microsoft visual studio",
                "sesi mata kuliah": "17.00 - 18.30",
                "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
                "referensi mata kuliah": "-"
            },
            {
                "kode mata kuliah": 1708020208,
                "mata kuliah": "dasar-dasar pemrograman ii",
                "sks": 2,
                "semester": "genap",
                "informasi mata kuliah": "studi tentang pemahaman lanjut pada pemrograman dan logika pemrograman.",
                "topik mata kuliah": "bahasa pemrograman c#, dasar pemrograman orientasi objek.",
                "software": "-",
                "sesi mata kuliah": "18.40 - 20.20",
                "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
                "referensi mata kuliah": "https://drive.google.com/open?id=1efozoh2s5y9ttb2pbyjoiu3g5mzrqwol"
            },
            {
                "kode mata kuliah": 1708020209,
                "mata kuliah": "praktikum dasar-dasar pemrograman ii",
                "sks": 1,
                "semester": "genap",
                "informasi mata kuliah": "studi tentang pemahaman lanjut pada pemrograman dan logika pemrograman",
                "topik mata kuliah": "bahasa pemrograman c#, dasar pemrograman orientasi objek.",
                "software": "microsoft visual studio",
                "sesi mata kuliah": "20.30 - 21.30",
                "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
                "referensi mata kuliah": "https://drive.google.com/open?id=1efozoh2s5y9ttb2pbyjoiu3g5mzrqwol"
            },
            {
                "kode mata kuliah": 1708030211,
                "mata kuliah": "aljabar linier",
                "sks": 2,
                "semester": "genap",
                "informasi mata kuliah": "studi tentang pemahaman lanjut pada matematika komputasi.",
                "topik mata kuliah": "vektor, ruang vektor, matriks, sistem persamaan linier, transformasi linier.",
                "software": "-",
                "sesi mata kuliah": "08.00 - 09.40",
                "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
                "referensi mata kuliah": "-"
            },
            {
                "kode mata kuliah": 1708020206,
                "mata kuliah": "pengantar sistem informasi bisnis",
                "sks": 2,
                "semester": "genap",
                "informasi mata kuliah": "studi mengenai pengaplikasian informasi seputar proses bisnis.",
                "topik mata kuliah": "manajemen bisnis, kasus – kasus bisnis.",
                "software": "-",
                "sesi mata kuliah": "09.50 - 11.30",
                "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
                "referensi mata kuliah": "https://drive.google.com/open?id=13hupgp-6fnggbsiwqi6quhoea5m8smb4"
            },
            {
       "kode mata kuliah": 1700000109,
       "mata kuliah": "pendidikan pancasila",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai dasar dan norma pada pancasila dan etika bela negara.",
       "topik mata kuliah": "pembahasan pancasila dalam kehidupan sehari – hari.",
       "software": "-",
       "sesi mata kuliah": "11.40 - 13.20",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708020202,
       "mata kuliah": "kalkulus",
       "sks": 3,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang pemahaman lanjut pada matematika komputasi.",
       "topik mata kuliah": "limit, integral dimensi 1, persamaan non linier.",
       "software": "-",
       "sesi mata kuliah": "13.30 - 15.10",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708020307,
       "mata kuliah": "sistem basis data",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai susunan / kumpulan data operasional lengkap dari suatu organisasi dan disimpan secara terintegrasi yang mampu menyediakan informasi secara optimal.",
       "topik mata kuliah": "perangkat dasar pada database manage system.",
       "software": "-",
       "sesi mata kuliah": "15.20 - 17.00",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "https://drive.google.com/open?id=16-rqoy7ebrxebxz2jkodssch1ixigou_"
     },
      {
       "kode mata kuliah": 1708020308,
       "mata kuliah": "praktikum sistem basis data",
       "sks": 1,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai susunan / kumpulan data operasional lengkap dari suatu organisasi dan disimpan secara terintegrasi yang mampu menyediakan informasi secara optimal.",
       "topik mata kuliah": "data manipulation (dml), data definition (ddl), data control (dcl)",
       "software": "xampp, mysql",
       "sesi mata kuliah": "17.00 - 18.30",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "https://drive.google.com/open?id=16-rqoy7ebrxebxz2jkodssch1ixigou_"
     },
      {
       "kode mata kuliah": 1708020348,
       "mata kuliah": "sistem operasi",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang perangkat lunak operasi pada suatu sistem dimana mengetahui dasar dan perintah pada sistem operasi.",
       "topik mata kuliah": "dasar dan teori pada sistem operasi, sinkronisasi, jadwal proses.",
       "software": "-",
       "sesi mata kuliah": "18.40 - 20.20",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "https://drive.google.com/open?id=1rtoexpk2eeyro7uya0bjzkwrnqz0-iee"
     },
      {
       "kode mata kuliah": 1708020349,
       "mata kuliah": "praktikum sistem operasi",
       "sks": 1,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang perangkat lunak operasi pada suatu sistem dimana mengetahui dasar dan perintah pada sistem operasi.",
       "topik mata kuliah": "dasar syntax pada os linux, syntax lanjut pada os linux.",
       "software": "virtualbox, linux iso",
       "sesi mata kuliah": "20.30 - 21.30",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1rtoexpk2eeyro7uya0bjzkwrnqz0-iee"
     },
      {
       "kode mata kuliah": 1708020304,
       "mata kuliah": "pengelolaan sistem komputer",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai manajemen perangkat lunak dan keras pada komputer.",
       "topik mata kuliah": "konsep dasar hardware, prinsip kerja dan perakitan komputer, perbaikan dan perawatan komputer.",
       "software": "-",
       "sesi mata kuliah": "08.00 - 09.40",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708020305,
       "mata kuliah": "manajemen sistem teknologi informasi",
       "sks": 4,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang pengaturan dan penerapan sistem teknologi pada perusahaan dan lain – lainnya.",
       "topik mata kuliah": "dasar – dasar pemrosesan, evousi tik, alur manajemen tik.",
       "software": "-",
       "sesi mata kuliah": "09.50 - 11.30",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708020346,
       "mata kuliah": "pemrograman visual",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang pemahaman lanjut pada pemrograman dan logika pemrograman secara visual.",
       "topik mata kuliah": "pengenalan pemrograman visual .net 2010, logika pemrograman berbasis visual.",
       "software": "-",
       "sesi mata kuliah": "11.40 - 13.20",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1yno8l2bqtq4n1kexusq5crmgftex7mkw"
     },
      {
       "kode mata kuliah": 1708020347,
       "mata kuliah": "praktikum pemrograman visual",
       "sks": 1,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang pemahaman lanjut pada pemrograman dan logika pemrograman secara visual.",
       "topik mata kuliah": "pengenalan pemrograman visual .net 2010, logika pemrograman berbasis visual.",
       "software": "microsoft visual studio",
       "sesi mata kuliah": "13.30 - 15.10",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1yno8l2bqtq4n1kexusq5crmgftex7mkw"
     },
      { 
       "kode mata kuliah": 1700000104,
       "mata kuliah": "olahraga/seni",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang dasar, teori, dan filosofi ilmu keolahragaan dan kesenian.",
       "topik mata kuliah": "filsafat olahraga, ontologi, aksiologi, epistimologi.",
       "software": "-",
       "sesi mata kuliah": "15.20 - 17.00",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1700000105,
       "mata kuliah": "pendidikan anti korupsi",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai ilmu hukum pada penindakan korupsi.",
       "topik mata kuliah": "pengertian korupsi, faktor penyebab korupsi, peran mahasiswa dalam gerakan antikorupsi.",
       "software": "-",
       "sesi mata kuliah": "17.00 - 18.30",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1700000106,
       "mata kuliah": "konservasi alam dan lingkungan",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang ilmu pengetahuan alam dan lingkugan pada lingkungan.",
       "topik mata kuliah": "ruang lingkup konservasi sumber daya alam dan lingkungan, sumber daya alam dalam lingkungan hidup dalam konteks pembangunan wilayah dan kawasan.",
       "software": "-",
       "sesi mata kuliah": "18.40 - 20.20",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708030208,
       "mata kuliah": "komunikasi data dan jaringan komputer",
       "sks": 4,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang manajemen data dan distribusi data pada komputer.",
       "topik mata kuliah": "sejarah perkembangan transmisi data, pengaplikasian pada kehidupan sehari – hari.",
       "software": "-",
       "sesi mata kuliah": "20.30 - 21.30",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "https://drive.google.com/open?id=1u1ntdmhybwzbqbwysokeuhumxuwhivtj"
     },
      {
       "kode mata kuliah": 1708020312,
       "mata kuliah": "perakitan dan instalasi jaringan komputer",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pendalaman perangkat – perangkat keras pada komputer dan kegunaannya masing – masing.",
       "topik mata kuliah": "prinsip kerja pada komputer, tata cara perakitan pada komputer.",
       "software": "-",
       "sesi mata kuliah": "08.00 - 09.40",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708020310,
       "mata kuliah": "organisasi dan arsitektur komputer",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pendalaman arsitektur dan pembangunan pada suatu perangkat komputer.",
       "topik mata kuliah": "sejarah perkembangan komputer, arsitektur pada komputer.",
       "software": "-",
       "sesi mata kuliah": "09.50 - 11.30",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708020314,
       "mata kuliah": "perancangan web",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai struktur dasar dan pengembangan pada web.",
       "topik mata kuliah": "definis web, dasar html dan css.",
       "software": "-",
       "sesi mata kuliah": "11.40 - 13.20",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "https://drive.google.com/open?id=1ad26b6vjsaghaemxkq4890c6i1frw2jt"
     },
      {
       "kode mata kuliah": 1708020315,
       "mata kuliah": "praktikum perancangan web",
       "sks": 1,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai struktur dasar dan pengembangan pada web.",
       "topik mata kuliah": "definis web, dasar html dan css.",
       "software": "sublime text 3, visual studio code, google web design",
       "sesi mata kuliah": "13.30 - 15.10",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1ad26b6vjsaghaemxkq4890c6i1frw2jt"
     },
      {
       "kode mata kuliah": 1708020316,
       "mata kuliah": "pengembangan sistem informasi",
       "sks": 4,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pengembangan lanjut pada teknologi sistem informasi dan tata cara pengembangan.",
       "topik mata kuliah": "software development life cycle, tata cara pengembangan sistem.",
       "software": "-",
       "sesi mata kuliah": "15.20 - 17.00",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708020317,
       "mata kuliah": "pemrograman berorientasi objek",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pemahaman lanjut pada pemrograman dan logika pemrograman secara objektif.",
       "topik mata kuliah": "pengenalan pemrograman berorientasi objek, bahasa pemrograman java",
       "software": "-",
       "sesi mata kuliah": "17.00 - 18.30",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "https://drive.google.com/open?id=1htzlrmvmixs4in-saicxgcpnnxvmu94d"
     },
      {
       "kode mata kuliah": 1708020318,
       "mata kuliah": "praktikum pemrograman berorientasi objek",
       "sks": 1,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pemahaman lanjut pada pemrograman dan logika pemrograman secara objektif.",
       "topik mata kuliah": "pengenalan pemrograman berorientasi objek, bahasa pemrograman java",
       "software": "netbeans",
       "sesi mata kuliah": "18.40 - 20.20",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1htzlrmvmixs4in-saicxgcpnnxvmu94d"
     },
      {
       "kode mata kuliah": 1708020306,
       "mata kuliah": "interaksi manusia dan teknologi komputer",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai dasar dan teori interkasi dan komunikasi berbasis teknologi komputer.",
       "topik mata kuliah": "prinsip dasar pendekatan antara manusia dengan komputer.",
       "software": "-",
       "sesi mata kuliah": "20.30 - 21.30",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708020311,
       "mata kuliah": "keamanan komputer",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang dasar – dasar keamanan informasi pada sistem teknologi.",
       "topik mata kuliah": "teknik enkripsi dan dekripsi, hacking defending.",
       "software": "-",
       "sesi mata kuliah": "08.00 - 09.40",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "https://drive.google.com/open?id=1w9oafzlfuza-lbpswlaeyhx1csrpflew"
     },
      {
       "kode mata kuliah": 1700000108,
       "mata kuliah": "bahasa inggris / toefl",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang ilmu bahasa inggris dan persiapan pada tes toefl.",
       "topik mata kuliah": "spelling, toefl topic, reading,  english conversation.",
       "software": "-",
       "sesi mata kuliah": "09.50 - 11.30",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1700000107,
       "mata kuliah": "kewirausahaan",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang ilmu bisnis dan wirausaha.",
       "topik mata kuliah": "role model wirausahawan, business design.",
       "software": "-",
       "sesi mata kuliah": "11.40 - 13.20",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708020320,
       "mata kuliah": "teknik riset operasional",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai riset lanjut tentang ilmu statistika mengenai operasional.",
       "topik mata kuliah": "optimalisasi, table simplex, logistik regression.",
       "software": "-",
       "sesi mata kuliah": "13.30 - 15.10",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "https://drive.google.com/open?id=1zyv0j3cjephqjcysztvkm5wcmx8douun"
     },
      {
       "kode mata kuliah": 1708020321,
       "mata kuliah": "pengolahan data terdistribusi",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai sistem lanjut pada penyebaran dan pengelolaan data.",
       "topik mata kuliah": "manajemen pendistribusian data, tata kelola dan perawatan pada server.",
       "software": "-",
       "sesi mata kuliah": "15.20 - 17.00",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708020322,
       "mata kuliah": "pemrograman berbasis web i",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang rancangan lanjut pada pengembangan web secara pemrograman.",
       "topik mata kuliah": "bahasa pemrograman php, pemrograman web lanjut dengan php.",
       "software": "-",
       "sesi mata kuliah": "17.00 - 18.30",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "https://drive.google.com/open?id=10veaud-c3jufkrq5jpisoebio4g42pry"
     },
      {
       "kode mata kuliah": 1708020323,
       "mata kuliah": "praktikum pemrograman berbasis web i",
       "sks": 1,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang rancangan lanjut pada pengembangan web secara pemrograman.",
       "topik mata kuliah": "bahasa pemrograman php, pemrograman web lanjut dengan php.",
       "software": "sublime text 3, visual studio code, google web design, xampp",
       "sesi mata kuliah": "18.40 - 20.20",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "https://drive.google.com/open?id=10veaud-c3jufkrq5jpisoebio4g42pry"
     },
      {
       "kode mata kuliah": 1708020324,
       "mata kuliah": "manajemen proyek sistem informasi",
       "sks": 3,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai manajemen dan perancangan sistem informasi pada proyek berbasis teknologi.",
       "topik mata kuliah": "dasar kerja pada proyek berbasis teknologi, manajemen pada proyek berbasis teknologi.",
       "software": "microsoft project",
       "sesi mata kuliah": "20.30 - 21.30",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708020313,
       "mata kuliah": "rekayasa perangkat lunak sistem informasi",
       "sks": 4,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai perancangan pada perangkat lunak pada sistem informasi.  ",
       "topik mata kuliah": "prinsip perkembangan software pada umumnya.",
       "software": "-",
       "sesi mata kuliah": "08.00 - 09.40",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708020319,
       "mata kuliah": "sistem pendukung keputusan",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang pengambilan keputusan pada suatu kasus berbasis teknologi informasi.",
       "topik mata kuliah": "teknik – teknik pada sistem pendukung keputusan.",
       "software": "-",
       "sesi mata kuliah": "09.50 - 11.30",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708020332,
       "mata kuliah": "rekayasa sistem berorientasi obyek",
       "sks": 3,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai perancangan sistem informasi berbasis objek.",
       "topik mata kuliah": "dasar penggunaan sistem berbasis objek, studi kasus dalam sistem berorientasi objek.",
       "software": "ibm rational rose, star uml",
       "sesi mata kuliah": "11.40 - 13.20",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708020210,
       "mata kuliah": "mobile programming",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang dasar – dasar pemroraman berbasis mobile.",
       "topik mata kuliah": "dasar – dasar pemrograman pada aplikasi berbasis mobile, logika  dasar pemrograman pada aplikasi mobile.",
       "software": "android studio, eclipse",
       "sesi mata kuliah": "13.30 - 15.10",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1fb8yklmft41xmshga0xibq_rc7tn8_la"
     },
      {
       "kode mata kuliah": 1708020327,
       "mata kuliah": "pemrograman berbasis web ii",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai manajemen dan perancangan sistem informasi pada proyek berbasis teknologi.",
       "topik mata kuliah": "pendalaman studi pada web design dengan html dan css.",
       "software": "-",
       "sesi mata kuliah": "15.20 - 17.00",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708020328,
       "mata kuliah": "praktikum pemrograman berbasis web ii",
       "sks": 1,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai manajemen dan perancangan sistem informasi pada proyek berbasis teknologi.",
       "topik mata kuliah": "pendalaman studi pada web design dengan html dan css.",
       "software": "sublime text 3, visual studio code, google web design, xampp",
       "sesi mata kuliah": "17.00 - 18.30",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708020329,
       "mata kuliah": "perancangan e-bisnis",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang rancang bangun aplikasi bisnis dan tata kelola bisnis elektronik.",
       "topik mata kuliah": "teori dasar pada e – business, tata kelola online shop.",
       "software": "-",
       "sesi mata kuliah": "18.40 - 20.20",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1qhxama7qs-etjivkrwlvn09lbhu25idc"
     },
      {
       "kode mata kuliah": 1708020330,
       "mata kuliah": "praktikum perancangan e-bisnis",
       "sks": 1,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang rancang bangun aplikasi bisnis dan tata kelola bisnis elektronik.",
       "topik mata kuliah": "teori dasar pada e – business, tata kelola online shop.",
       "software": "xampp, prestashop",
       "sesi mata kuliah": "20.30 - 21.30",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "https://drive.google.com/open?id=1qhxama7qs-etjivkrwlvn09lbhu25idc"
     },
      {
       "kode mata kuliah": 1708020331,
       "mata kuliah": "enterprise resource planning",
       "sks": 3,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pengembangan dan perancangan lanjut pada sistem bisnis.",
       "topik mata kuliah": "pendalaman lanjut pada studi e – commerce.",
       "software": "openerp, openbravo",
       "sesi mata kuliah": "08.00 - 09.40",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708020325,
       "mata kuliah": "testing dan implementasi sistem",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai analisa dan implementasu uji aplikasi.",
       "topik mata kuliah": "dasar perbandingan antara white box testig dan black box testing. prinsip dan tujuan pada percobaan aplikasi.",
       "software": "-",
       "sesi mata kuliah": "09.50 - 11.30",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708020501,
       "mata kuliah": "etika profesi teknologi informasi",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang kaidah dan norma perilaku seorang it pada dunia kerja.",
       "topik mata kuliah": "pengenalan etika it pada dunia kerja, studi kasus pada dunia it.",
       "software": "-",
       "sesi mata kuliah": "11.40 - 13.20",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708030308,
       "mata kuliah": "metodologi penelitian teknologi informasi",
       "sks": 3,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai kaidah – kaidah pada penelitian dan susunan metode pada teknologi informasi.",
       "topik mata kuliah": "panduan pemilihan jurnal, tata cara penelitian.",
       "software": "-",
       "sesi mata kuliah": "13.30 - 15.10",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708020334,
       "mata kuliah": "audit sistem informasi",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang implementasi dan dasar – dasar informasi pada sistem audit.",
       "topik mata kuliah": "efektifitas dan efisiensi pada sistem, pengontrolan dan pengamanan dalam integritas  suatu data.",
       "software": "-",
       "sesi mata kuliah": "15.20 - 17.00",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
      {
       "kode mata kuliah": 1708020343,
       "mata kuliah": "big data analysis & bussines inteligent",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pemahaman ilmu data dan analisa dalam bisnis secara komputasi.",
       "topik mata kuliah": "studi riset tentang bi & big data pada dunia bisnis.",
       "software": "pentaho, tableau",
       "sesi mata kuliah": "17.00 - 18.30",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "https://drive.google.com/open?id=1qhxama7qs-etjivkrwlvn09lbhu25idc"
     },
     {
       "kode mata kuliah": 1708020211,
       "mata kuliah": "sistem berbasis pengetahuan",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai dasar – dasar informasi berbasis pengetahuan dan perkembangan teknologi informasi.",
       "topik mata kuliah": "dasar – dasar tentang ai, sistem pengembangan pada ai.",
       "software": "-",
       "sesi mata kuliah": "18.40 - 20.20",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1muzi8ia-sr5l-tskbjsjdefwwaev7dmo"
     },
     {
       "kode mata kuliah": 1708020502,
       "mata kuliah": "keterampilan berkomunikasi",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai tata cara berkomunikasi dan penyampaian pesan secara efektif.",
       "topik mata kuliah": "studi tentang pencarian jati diri, studi kerja kelompok pada proyek.",
       "software": "-",
       "sesi mata kuliah": "20.30 - 21.30",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708020326,
       "mata kuliah": "grafik komputer",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang perancangan desain grafik komputer berbasis pemrograman.",
       "topik mata kuliah": "dasar – dasar pemrograman pada komputer berbasis grafik.",
       "software": "processing, microsoft visual studio, codeblocks",
       "sesi mata kuliah": "08.00 - 09.40",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "https://drive.google.com/open?id=1joqj18wf5ksrm7fdkrcewhrxvwhy1ji7"
     },
     {
       "kode mata kuliah": 1708020309,
       "mata kuliah": "sistem terdistribusi",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang teori dasar da perancangan lanjut pada pendistribusian suatu data.",
       "topik mata kuliah": "prinsip dasar pendistribusian data pada jaringan komputer.",
       "software": "-",
       "sesi mata kuliah": "09.50 - 11.30",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708020205,
       "mata kuliah": "change management",
       "sks": 3,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang dasar – dasar pemrograman aplikasi perkantoran.",
       "topik mata kuliah": "dasar penggunaan aplikasi perkantoran.",
       "software": "microsoft office",
       "sesi mata kuliah": "11.40 - 13.20",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708020336,
       "mata kuliah": "perancangan basis data lanjut",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai rancangan lanjut basis data secara kompleks.",
       "topik mata kuliah": "pemahaman lanjut mengenai basis data pada sistem enterprises.",
       "software": "oracle databases xe",
       "sesi mata kuliah": "13.30 - 15.10",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "https://drive.google.com/open?id=1rc7kqnnb81p5yxla57kyfxcl06ds6dnn"
     },
     {
       "kode mata kuliah": 1708020404,
       "mata kuliah": "tugas akhir",
       "sks": 6,
       "semester": "ganjil / genap",
       "informasi mata kuliah": "-",
       "topik mata kuliah": "-",
       "software": "-",
       "sesi mata kuliah": "-",
       "mahasiswa mata kuliah": "-",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030206,
       "mata kuliah": "kalkulus i",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai matematika dasar pada komputasi.",
       "topik mata kuliah": "limit, integral dimensi 1, persamaan non linier.",
       "software": "-",
       "sesi mata kuliah": "08.00 - 09.40",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030209,
       "mata kuliah": "fisika dasar",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang dasar – dasar fisika pada komputasi.",
       "topik mata kuliah": "rangkaian paralel dan seri, looping, dasar biner.",
       "software": "-",
       "sesi mata kuliah": "09.50 - 11.30",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030217,
       "mata kuliah": "praktikum fisika dasar",
       "sks": 1,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang dasar – dasar fisika pada komputasi.",
       "topik mata kuliah": "rangkaian paralel dan seri, looping, dasar biner.",
       "software": "-",
       "sesi mata kuliah": "11.40 - 13.20",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1700000101,
       "mata kuliah": "pendidikan kewarnegaraan",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "sebuah ilmu atau studi mengenai tugas dan kewajiban pemerintahan serta hak dan kewajiban seorang warga negara.",
       "topik mata kuliah": "hak dan kewajiban warga negaranya, jati diri atau identitas bangsa dan negara, konstitusi negara.",
       "software": "-",
       "sesi mata kuliah": "13.30 - 15.10",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030201,
       "mata kuliah": "algoritma dan pemrograman i",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang dasar pada pemrograman dan logika pemrograman.",
       "topik mata kuliah": "dasar logika pemrograman, bahasa pemrograman c++",
       "software": "",
       "sesi mata kuliah": "15.20 - 17.00",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "https://drive.google.com/open?id=1rkxygthotentcfcnw-toksqfjfo78dlt"
     },
     {
       "kode mata kuliah": 1708030215,
       "mata kuliah": "praktikum algoritma dan pemrograman i",
       "sks": 1,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang dasar pada pemrograman dan logika pemrograman.",
       "topik mata kuliah": "dasar logika pemrograman, bahasa pemrograman c++",
       "software": "dev  c++, turbo c++",
       "sesi mata kuliah": "17.00 - 18.30",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1rkxygthotentcfcnw-toksqfjfo78dlt"
     },
     {
       "kode mata kuliah": 1708030214,
       "mata kuliah": "pengantar teknologi komunikasi dan informatika",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai pengantar teknologi sebagai dasar – dasar teknologi.",
       "topik mata kuliah": "dasar software dan hardware, implementasi dalam kehidupan sehari – hari.",
       "software": "-",
       "sesi mata kuliah": "18.40 - 20.20",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1700000102,
       "mata kuliah": "bahasa indonesia",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai ilmu bahasa yang dimana dapat mendorong mahasiswa menggunakan bahasa yang sesuai dengan kaidah dan norma yang berlaku.",
       "topik mata kuliah": "sejarah bahasa indonesia, komunikasi lisan dan kalimat induktif.",
       "software": "-",
       "sesi mata kuliah": "20.30 - 21.30",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030203,
       "mata kuliah": "aljabar linier",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang pemahaman lanjut pada matematika komputasi.",
       "topik mata kuliah": "matriks, persamaan linier.",
       "software": "-",
       "sesi mata kuliah": "08.00 - 09.40",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708020101,
       "mata kuliah": "bahasa inggris informatika",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang ilmu bahasa inggris pada konteks keilmuan informatika.",
       "topik mata kuliah": "tenses, dasar bahasa informatika, studi kasus dalam teknologi.",
       "software": "-",
       "sesi mata kuliah": "09.50 - 11.30",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030207,
       "mata kuliah": "kalkulus ii",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pemahaman lanjut pada matematika komputasi.",
       "topik mata kuliah": "persamaan linier, integral 2 & 3 dimensi, matematika turunun.",
       "software": "-",
       "sesi mata kuliah": "11.40 - 13.20",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030202,
       "mata kuliah": "algoritma dan pemrograman ii",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pemahaman lanjut pada pemrograman dan logika pemrograman.",
       "topik mata kuliah": "bahasa pemrograman c#, dasar pemrograman orientasi objek.",
       "software": "",
       "sesi mata kuliah": "13.30 - 15.10",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1qznag0txy4jqqgjwpn9icqff44rd9_2h"
     },
     {
       "kode mata kuliah": 1708030216,
       "mata kuliah": "praktikum algoritma dan pemrograman ii",
       "sks": 1,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pemahaman lanjut pada pemrograman dan logika pemrograman.",
       "topik mata kuliah": "bahasa pemrograman c#, dasar pemrograman orientasi objek.",
       "software": "microsoft visual studio",
       "sesi mata kuliah": "15.20 - 17.00",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1qznag0txy4jqqgjwpn9icqff44rd9_2h"
     },
     {
       "kode mata kuliah": 1708030220,
       "mata kuliah": "statistika dan probabilitas",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai ilmu statistika dan dasar perhitungan pada penerapan teknologi.",
       "topik mata kuliah": "mean, median, modus.",
       "software": "-",
       "sesi mata kuliah": "17.00 - 18.30",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "https://drive.google.com/open?id=1ksy6ir7g0s8imodza_2haubcedbim2ne"
     },
     {
       "kode mata kuliah": 1708030211,
       "mata kuliah": "matematika diskrit",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai dasar – dasar matematika teknologi.",
       "topik mata kuliah": "aritmatika, peluang, himpunan.",
       "software": "-",
       "sesi mata kuliah": "18.40 - 20.20",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030221,
       "mata kuliah": "struktur data dan algoritma",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang analisa struktur pemrograman dan dasar algoritma pada pemrograman.",
       "topik mata kuliah": "dasar algoritma, stack and queue.",
       "software": "-",
       "sesi mata kuliah": "20.30 - 21.30",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030219,
       "mata kuliah": "praktikum struktur data dan algoritma",
       "sks": 1,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang analisa struktur pemrograman dan dasar algoritma pada pemrograman.",
       "topik mata kuliah": "dasar algoritma, stack and queue.",
       "software": "-",
       "sesi mata kuliah": "08.00 - 09.40",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030213,
       "mata kuliah": "sistem digital",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pemahaman lanjut dalam ilmu fisika dasar yang berbasis digital.",
       "topik mata kuliah": "konversi bahasa mesin.",
       "software": "-",
       "sesi mata kuliah": "09.50 - 11.30",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030218,
       "mata kuliah": "praktikum sistem digital",
       "sks": 1,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pemahaman lanjut dalam ilmu fisika dasar yang berbasis digital.",
       "topik mata kuliah": "konversi bahasa mesin.",
       "software": "-",
       "sesi mata kuliah": "11.40 - 13.20",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708020346,
       "mata kuliah": "pemrograman visual",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pemahaman lanjut pada pemrograman dan logika pemrograman secara visual.",
       "topik mata kuliah": "pengenalan pemrograman visual .net 2010, logika pemrograman berbasis visual.",
       "software": "-",
       "sesi mata kuliah": "13.30 - 15.10",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "https://drive.google.com/open?id=1pzc5qlwnbrgrhhwwhfbhvgooaucmd6o_"
     },
     {
       "kode mata kuliah": 1708020347,
       "mata kuliah": "praktikum pemrograman visual",
       "sks": 1,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pemahaman lanjut pada pemrograman dan logika pemrograman secara visual.",
       "topik mata kuliah": "pengenalan pemrograman visual .net 2010, logika pemrograman berbasis visual.",
       "software": "microsoft visual studio",
       "sesi mata kuliah": "15.20 - 17.00",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1pzc5qlwnbrgrhhwwhfbhvgooaucmd6o_"
     },
     {
       "kode mata kuliah": 1708030502,
       "mata kuliah": "komputer dan masyarakat",
       "sks": 3,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai sosialisasi dalam bemasyarakat dilingkungan sekitar melalui jaringan teknologi.",
       "topik mata kuliah": "isu - isu sosial dalam pandangan terkini, ruang lingkup masyarakat teknologi.",
       "software": "-",
       "sesi mata kuliah": "17.00 - 18.30",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1700000103,
       "mata kuliah": "pendidikan agama",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai ilmu kerohanian dimana dapat membangun keimanan dan ketaqwaan kepada tuhan yang maha esa.",
       "topik mata kuliah": "pengantar rukun iman dan islam, pengabdian masyarakat.",
       "software": "-",
       "sesi mata kuliah": "18.40 - 20.20",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": ""
     },
     {
       "kode mata kuliah": 1708030210,
       "mata kuliah": "logika informatika",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang perhitungan dan pemahaman argumentasi pada pemrograman.",
       "topik mata kuliah": "logika or dan and pada pemrograman dan matematka informatika.",
       "software": "-",
       "sesi mata kuliah": "20.30 - 21.30",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030309,
       "mata kuliah": "arsitektur dan organisasi komputer",
       "sks": 3,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang pendalaman arsitektur dan pembangunan pada suatu perangkat komputer.",
       "topik mata kuliah": "sejarah perkembangan komputer, arsitektur pada komputer.",
       "software": "-",
       "sesi mata kuliah": "08.00 - 09.40",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030327,
       "mata kuliah": "basis data",
       "sks": 4,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai susunan / kumpulan data operasional lengkap dari suatu organisasi dan disimpan secara terintegrasi yang mampu menyediakan informasi secara optimal.",
       "topik mata kuliah": "data manipulation (dml), data definition (ddl), data control (dcl)",
       "software": "-",
       "sesi mata kuliah": "09.50 - 11.30",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "https://drive.google.com/open?id=16-rqoy7ebrxebxz2jkodssch1ixigou_"
     },
     {
       "kode mata kuliah": 1708020348,
       "mata kuliah": "sistem operasi",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang perangkat lunak operasi pada suatu sistem dimana mengetahui dasar dan perintah pada sistem operasi.",
       "topik mata kuliah": "dasar dan teori pada sistem operasi, sinkronisasi, jadwal proses.",
       "software": "-",
       "sesi mata kuliah": "11.40 - 13.20",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1crm1sklxxfbvpuki0oyiorjisbkbmpmz"
     },
     {
       "kode mata kuliah": 1708020349,
       "mata kuliah": "praktikum sistem operasi",
       "sks": 1,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang perangkat lunak operasi pada suatu sistem dimana mengetahui dasar dan perintah pada sistem operasi.",
       "topik mata kuliah": "dasar syntax pada os linux, syntax lanjut pada os linux.",
       "software": "virtual box, linux os",
       "sesi mata kuliah": "13.30 - 15.10",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1crm1sklxxfbvpuki0oyiorjisbkbmpmz"
     },
     {
       "kode mata kuliah": 1708030318,
       "mata kuliah": "perancangan dan analisa algoritma",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai perhitungan algoritma pada logika pemrograman",
       "topik mata kuliah": "dasar – dasar algoritma, teknik dasar algoritma.",
       "software": "-",
       "sesi mata kuliah": "15.20 - 17.00",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "https://drive.google.com/open?id=1y08jfimiv-5fg1cjosa0umftyapbghku"
     },
     {
       "kode mata kuliah": 1708030303,
       "mata kuliah": "e-business",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang rancang bangun aplikasi bisnis dan tata kelola bisnis elektronik.",
       "topik mata kuliah": "teori dasar pada e – business, tata kelola online shop.",
       "software": "-",
       "sesi mata kuliah": "17.00 - 18.30",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1y9t9eu_4sbbbcnsl5n8xcwhf0liwe74u"
     },
     {
       "kode mata kuliah": 1708030320,
       "mata kuliah": "praktikum e-business",
       "sks": 1,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang rancang bangun aplikasi bisnis dan tata kelola bisnis elektronik.",
       "topik mata kuliah": "teori dasar pada e – business, tata kelola online shop.",
       "software": "xampp, prestashop",
       "sesi mata kuliah": "18.40 - 20.20",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1y9t9eu_4sbbbcnsl5n8xcwhf0liwe74u"
     },
     {
       "kode mata kuliah": 1700000109,
       "mata kuliah": "pancasila",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai dasar dan norma pada pancasila dan etika bela negara.",
       "topik mata kuliah": "sejarah uud 1945, arti dalam pada pancasila.",
       "software": "-",
       "sesi mata kuliah": "20.30 - 21.30",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": ""
     },
     {
       "kode mata kuliah": 1708020317,
       "mata kuliah": "pemrograman berorientasi objek",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pemahaman lanjut pada pemrograman dan logika pemrograman secara objektif.",
       "topik mata kuliah": "pengenalan pemrograman berorientasi objek, bahasa pemrograman java",
       "software": "-",
       "sesi mata kuliah": "08.00 - 09.40",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1e2xupxe3xzmnt4varp0sebdj-z_pvx8t"
     },
     {
       "kode mata kuliah": 1708020318,
       "mata kuliah": "praktikum pemrograman berorientasi objek",
       "sks": 1,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pemahaman lanjut pada pemrograman dan logika pemrograman secara objektif.",
       "topik mata kuliah": "pengenalan pemrograman berorientasi objek, bahasa pemrograman java",
       "software": "netbeans",
       "sesi mata kuliah": "09.50 - 11.30",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1e2xupxe3xzmnt4varp0sebdj-z_pvx8t"
     },
     {
       "kode mata kuliah": 1708030305,
       "mata kuliah": "interaksi manusia dan komputer",
       "sks": 3,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai dasar dan teori interkasi dan komunikasi berbasis teknologi komputer.",
       "topik mata kuliah": "prinsip dasar pendekatan antara manusia dengan komputer.",
       "software": "-",
       "sesi mata kuliah": "11.40 - 13.20",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030212,
       "mata kuliah": "metode numerik",
       "sks": 3,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pendalaman pada matematika komputasi numerik.",
       "topik mata kuliah": "integrasi numerik, biseksi.",
       "software": "-",
       "sesi mata kuliah": "13.30 - 15.10",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030302,
       "mata kuliah": "bahasa dan automata",
       "sks": 3,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai pendalaman pada logika dan argumentasi dalam pemrograman.",
       "topik mata kuliah": "dasar turunan pada pemrograman.",
       "software": "-",
       "sesi mata kuliah": "15.20 - 17.00",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030208,
       "mata kuliah": "komunikasi data dan jaringan komputer",
       "sks": 4,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang manajemen data dan distribusi data pada komputer.",
       "topik mata kuliah": "sejarah perkembangan transmisi data, pengaplikasian pada kehidupan sehari – hari.",
       "software": "-",
       "sesi mata kuliah": "17.00 - 18.30",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030316,
       "mata kuliah": "pengelolaan instalasi komputer",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pendalaman perangkat – perangkat keras pada komputer dan kegunaannya masing – masing.",
       "topik mata kuliah": "prinsip kerja pada komputer, tata cara perakitan pada komputer.",
       "software": "-",
       "sesi mata kuliah": "18.40 - 20.20",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030325,
       "mata kuliah": "praktikum pengelolaan instalasi komputer",
       "sks": 1,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pendalaman perangkat – perangkat keras pada komputer dan kegunaannya masing – masing.",
       "topik mata kuliah": "prinsip kerja pada komputer, tata cara perakitan pada komputer.",
       "software": "-",
       "sesi mata kuliah": "20.30 - 21.30",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030310,
       "mata kuliah": "pemrograman bergerak",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang dasar – dasar pemroraman berbasis mobile.",
       "topik mata kuliah": "dasar – dasar pemrograman pada aplikasi berbasis mobile, logika  dasar pemrograman pada aplikasi mobile.",
       "software": "android studio, eclipse",
       "sesi mata kuliah": "08.00 - 09.40",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "https://drive.google.com/open?id=1gyr9kachw--ovsl9x0i7goffyya702pv"
     },
     {
       "kode mata kuliah": 1708030330,
       "mata kuliah": "teknik kompilasi",
       "sks": 3,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai dasar – dasar dan teknik perhitungan komputasi.",
       "topik mata kuliah": "pembelajaran bahasa mesin, teknik dasar penggunaan dalam bahasa mesin.",
       "software": "-",
       "sesi mata kuliah": "09.50 - 11.30",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030329,
       "mata kuliah": "teknik riset operasional",
       "sks": 4,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai riset lanjut tentang ilmu statistika mengenai operasional.",
       "topik mata kuliah": "dasar perbandingan antara white box testig dan black box testing. prinsip dan tujuan pada percobaan aplikasi.",
       "software": "-",
       "sesi mata kuliah": "11.40 - 13.20",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1zyv0j3cjephqjcysztvkm5wcmx8douun"
     },
     {
       "kode mata kuliah": 1708030313,
       "mata kuliah": "pemrograman multimedia",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang desain, aspek, dan animasi pada pemrograman berbasis multimedia.",
       "topik mata kuliah": "penggunaan adobe illustrator dalam pembuatan animasi.",
       "software": "-",
       "sesi mata kuliah": "13.30 - 15.10",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "https://drive.google.com/open?id=1joqj18wf5ksrm7fdkrcewhrxvwhy1ji7"
     },
     {
       "kode mata kuliah": 1708030322,
       "mata kuliah": "praktikum pemrograman multimedia",
       "sks": 1,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang desain, aspek, dan animasi pada pemrograman berbasis multimedia.",
       "topik mata kuliah": "penggunaan adobe illustrator dalam pembuatan animasi.",
       "software": "autodesk 3d max, corel draw",
       "sesi mata kuliah": "15.20 - 17.00",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1joqj18wf5ksrm7fdkrcewhrxvwhy1ji7"
     },
     {
       "kode mata kuliah": 1708030301,
       "mata kuliah": "algoritma pararel",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai pemahaman lanjut matematika pemrograman.",
       "topik mata kuliah": "kebutuhan dan pengolahan paralel, notasi paralel, pram.",
       "software": "-",
       "sesi mata kuliah": "17.00 - 18.30",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030304,
       "mata kuliah": "grafik komputer",
       "sks": 3,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang perancangan desain grafik komputer berbasis pemrograman.",
       "topik mata kuliah": "dasar – dasar pemrograman pada komputer berbasis grafik.",
       "software": "processing",
       "sesi mata kuliah": "18.40 - 20.20",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030306,
       "mata kuliah": "kecerdasan buatan dan logika fuzzy",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang penjabaran logika dalam sebuah komputasi buatan.",
       "topik mata kuliah": "logika fuzzy, implementasi algoritma fuzzy.",
       "software": "matlab",
       "sesi mata kuliah": "20.30 - 21.30",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1muzi8ia-sr5l-tskbjsjdefwwaev7dmo"
     },
     {
       "kode mata kuliah": 1700000107,
       "mata kuliah": "kewirausahaan",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang ilmu bisnis dan wirausaha.",
       "topik mata kuliah": "role model wirausahawan, business design.",
       "software": "-",
       "sesi mata kuliah": "08.00 - 09.40",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1700000104,
       "mata kuliah": "olahraga/seni",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang dasar, teori, dan filosofi ilmu keolahragaan dan kesenian.",
       "topik mata kuliah": "filsafat olahraga, ontologi, aksiologi, epistimologi.",
       "software": "-",
       "sesi mata kuliah": "09.50 - 11.30",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1700000105,
       "mata kuliah": "konservasi alam dan lingkungan",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang ilmu pengetahuan alam dan lingkugan pada lingkungan.",
       "topik mata kuliah": "ruang lingkup konservasi sumber daya alam dan lingkungan, sumber daya alam dalam lingkungan hidup dalam konteks pembangunan wilayah dan kawasan.",
       "software": "-",
       "sesi mata kuliah": "11.40 - 13.20",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1700000106,
       "mata kuliah": "pendidikan anti korupsi",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai ilmu hukum pada penindakan korupsi.",
       "topik mata kuliah": "pengertian korupsi, faktor penyebab korupsi, peran mahasiswa dalam gerakan antikorupsi.",
       "software": "-",
       "sesi mata kuliah": "13.30 - 15.10",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708020501,
       "mata kuliah": "etika profesi teknologi informasi",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang kaidah dan norma perilaku seorang it pada dunia kerja.",
       "topik mata kuliah": "pengenalan etika it pada dunia kerja, studi kasus pada dunia it.",
       "software": "-",
       "sesi mata kuliah": "15.20 - 17.00",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030315,
       "mata kuliah": "pemrograman web",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai struktur dasar dan pengembangan pada web.",
       "topik mata kuliah": "definis web, dasar html dan css.",
       "software": "-",
       "sesi mata kuliah": "17.00 - 18.30",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1se21dlcn8tkb00fwvgapqln8jrninnzf"
     },
     {
       "kode mata kuliah": 1708030324,
       "mata kuliah": "praktikum pemrograman web",
       "sks": 1,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai struktur dasar dan pengembangan pada web.",
       "topik mata kuliah": "definis web, dasar html dan css.",
       "software": "sublime text 3 / visual codes/ adobe dreamweaver",
       "sesi mata kuliah": "18.40 - 20.20",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1se21dlcn8tkb00fwvgapqln8jrninnzf"
     },
     {
       "kode mata kuliah": 1708030222,
       "mata kuliah": "teknik simulasi dan permodelan",
       "sks": 3,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pengujian dalam perhitungan pemrograman.",
       "topik mata kuliah": "dasar dan simulasi program dengan bahasa c.",
       "software": "-",
       "sesi mata kuliah": "20.30 - 21.30",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": null,
       "mata kuliah": "rekayasa perangkat lunak",
       "sks": 4,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai perancangan pada perangkat lunak pada sistem informasi.",
       "topik mata kuliah": "prinsip perkembangan software pada umumnya.",
       "software": "-",
       "sesi mata kuliah": "08.00 - 09.40",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030308,
       "mata kuliah": "metodologi penelitian teknologi informasi",
       "sks": 3,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai kaidah – kaidah pada penelitian dan susunan metode pada teknologi informasi.",
       "topik mata kuliah": "panduan pemilihan jurnal, tata cara penelitian.",
       "software": "-",
       "sesi mata kuliah": "09.50 - 11.30",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030317,
       "mata kuliah": "pengolahan citra",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pengukuran dan perhitungan dalam media berbentuk pemrograman.",
       "topik mata kuliah": "citra 2 dimensi, teknik penghilangan noise pada gambar, citra biner, pengenalan pola.",
       "software": "matlab",
       "sesi mata kuliah": "11.40 - 13.20",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1700000108,
       "mata kuliah": "toefl/bahasa inggris",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang ilmu bahasa inggris dan persiapan pada tes toefl.",
       "topik mata kuliah": "spelling, toefl topic, reading,  english conversation.",
       "software": "-",
       "sesi mata kuliah": "13.30 - 15.10",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030307,
       "mata kuliah": "manajemen proyek teknologi informasi",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai manajemen dan perancangan sistem informasi pada proyek berbasis teknologi.",
       "topik mata kuliah": "dasar kerja pada proyek berbasis teknologi, manajemen pada proyek berbasis teknologi.",
       "software": "microsoft office project",
       "sesi mata kuliah": "15.20 - 17.00",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708020205,
       "mata kuliah": "sistem terdistribusi",
       "sks": 3,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang teori dasar da perancangan lanjut pada pendistribusian suatu data.",
       "topik mata kuliah": "prinsip dasar pendistribusian data pada jaringan komputer.",
       "software": "-",
       "sesi mata kuliah": "17.00 - 18.30",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708020502,
       "mata kuliah": "keterampilan berkomunikasi",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai tata cara berkomunikasi dan penyampaian pesan secara efektif.",
       "topik mata kuliah": "studi tentang pencarian jati diri, studi kerja kelompok pada proyek.",
       "software": "-",
       "sesi mata kuliah": "18.40 - 20.20",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030402,
       "mata kuliah": "kerja praktek",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "-",
       "topik mata kuliah": "-",
       "software": "-",
       "sesi mata kuliah": "-",
       "mahasiswa mata kuliah": "-",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030403,
       "mata kuliah": "tugas akhir",
       "sks": 6,
       "semester": "ganjil",
       "informasi mata kuliah": "-",
       "topik mata kuliah": "-",
       "software": "-",
       "sesi mata kuliah": "-",
       "mahasiswa mata kuliah": "-",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030616,
       "mata kuliah": "teknologi multimedia",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai pengantaran dari desain grafis multimedia dan pendalaman perangakat desain multimedia.",
       "topik mata kuliah": "standar dan sistem komunikasi multimedia, teknologi telekonfrensi dan video broadcasting.",
       "software": "autodesk 3d max, adobe photoshop, adobe illustrator.",
       "sesi mata kuliah": "09.50 - 11.30",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030614,
       "mata kuliah": "sistem informasi geografis",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai ilmu geografis dalam sistem berbasis komputasi.",
       "topik mata kuliah": "penggunaan aplikasi mapinfo, sistem pemetaan.",
       "software": "mapinfo",
       "sesi mata kuliah": "11.40 - 13.20",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "https://drive.google.com/open?id=15epgcwylksc5lyq91t3hdudswj06eaxs"
     },
     {
       "kode mata kuliah": 1708030312,
       "mata kuliah": "pemrograman game",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pemahaman dan perkembangan dalam game.",
       "topik mata kuliah": "storyline, desain animasi 3d.",
       "software": "unity",
       "sesi mata kuliah": "13.30 - 15.10",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030607,
       "mata kuliah": "keamanan jaringan komputer",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang pendalaman sekuritas pada jaringan komputer.",
       "topik mata kuliah": "pengertian cybercrime, dasar - dasar enkripsi dan dekripsi",
       "software": "-",
       "sesi mata kuliah": "15.20 - 17.00",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1w9oafzlfuza-lbpswlaeyhx1csrpflew"
     },
     {
       "kode mata kuliah": 1708030606,
       "mata kuliah": "jaringan nirkabel dan komputasi bergerak",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai pemahaman lanjut pada perangkat jaringan nirkabel.",
       "topik mata kuliah": "konfigurasi jaringan pada sebuah perangkat nirkabel, desain bangun jaringan nirkabel.",
       "software": "-",
       "sesi mata kuliah": "17.00 - 18.30",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030608,
       "mata kuliah": "komunikasi serat optik",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang penggunaan fiber optik pada perangkat jaringan.",
       "topik mata kuliah": "pengertian kabel optik, cahaya, dan struktur kabel.",
       "software": "-",
       "sesi mata kuliah": "18.40 - 20.20",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030602,
       "mata kuliah": "cloud computing",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai pemanfaatan teknologi komputasi dan pengembangan internet berbasis awan.",
       "topik mata kuliah": "services cloud computing, implementasi cloud computing di era sekarang.",
       "software": "-",
       "sesi mata kuliah": "20.30 - 21.30",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030609,
       "mata kuliah": "kriptografi",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi tentang ilmu konversi komunikasi yang dimana bertujuan dalam kerahasiaan suatu data.",
       "topik mata kuliah": "teknik enkripsi dan dekripsi, hacking defending.",
       "software": "-",
       "sesi mata kuliah": "08.00 - 09.40",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030612,
       "mata kuliah": "desain sistem berorientasi objek",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai perancangan sistem informasi berbasis objek.",
       "topik mata kuliah": "dasar penggunaan sistem berbasis objek, studi kasus dalam sistem berorientasi objek.",
       "software": "ibm rational rose, star uml",
       "sesi mata kuliah": "09.50 - 11.30",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030613,
       "mata kuliah": "sistem berbasis pengetahuan dan sistem cerdas",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai dasar – dasar informasi berbasis pengetahuan dan perkembangan teknologi informasi.",
       "topik mata kuliah": "dasar dari sistem berbasis pengetahuan, fungsi dan implementasi ai berbasis pengentahuan.",
       "software": "-",
       "sesi mata kuliah": "11.40 - 13.20",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "https://drive.google.com/open?id=10umcsbwknill0-zx8v1gt6r8n2pgtk_g"
     },
     {
       "kode mata kuliah": 1708030615,
       "mata kuliah": "sistem jaringan syaraf tiruan",
       "sks": 2,
       "semester": "genap",
       "informasi mata kuliah": "studi mengenai pemahaman mengenai syaraf tiruan berbasis matematika komputasi",
       "topik mata kuliah": "pengertian jaringan syaraf tiruan, karakteristik jaringan syaraf tiruan, implementasi dan metode / algoritma pada jaringan syaraf tiruan.",
       "software": "-",
       "sesi mata kuliah": "13.30 - 15.10",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1cj8dxiz28vfv1pxhwk1aowxtff3oaeun"
     },
     {
       "kode mata kuliah": 1708030601,
       "mata kuliah": "animasi komputer",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai pendalaman lanjut dari desain komputasi grafik dan media.",
       "topik mata kuliah": "animasi 2d dan 3d, dasar desain grafis.",
       "software": "autodesk 3dmax, autodesk maya",
       "sesi mata kuliah": "15.20 - 17.00",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "https://drive.google.com/open?id=1joqj18wf5ksrm7fdkrcewhrxvwhy1ji7"
     },
     {
       "kode mata kuliah": 1708030603,
       "mata kuliah": "computer vision",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang ilmu komputer yang dimana dapa bekerja sesuai penglihatan manusia.",
       "topik mata kuliah": "image processing (pengolahan citra) dan machine vision (visi mesin).",
       "software": "anaconda jupyter",
       "sesi mata kuliah": "17.00 - 18.30",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "https://drive.google.com/open?id=16ifsnf_ezrahcbtdbrdobnpoqp1nnpx3"
     },
     {
       "kode mata kuliah": 1708030605,
       "mata kuliah": "interface dan peripheral",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang pengembangan penghubung suatu perangkat komputer dengan komputer yang lain.",
       "topik mata kuliah": "penggunaan arduino, dasar mikrokontroler dan sensorik.",
       "software": "-",
       "sesi mata kuliah": "18.40 - 20.20",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030601,
       "mata kuliah": "perancangan dan manajemen jaringan",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang pengaturan cakupan wilayah pada penggunaan perangkat jaringan.",
       "topik mata kuliah": "standar osi model dan ieee 802, perancangan dan administrasi jaringan, simple network management protocol.",
       "software": "gns3, cisco packet tracer",
       "sesi mata kuliah": "20.30 - 21.30",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030603,
       "mata kuliah": "pemrograman jaringan",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang pemrograman dan perawatan pada perangkat jaringan.",
       "topik mata kuliah": "pengantar jaringan, pemrograman http, stream i/o, komunikasi antar objek.",
       "software": "ns2",
       "sesi mata kuliah": "08.00 - 09.40",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "https://drive.google.com/open?id=1p1z7fpd2nx7ct8ivwdv0yb-czis5zfnw"
     },
     {
       "kode mata kuliah": null,
       "mata kuliah": "sistem komunikasi gelombang mikro",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai pemahaman lanjut pada penggunaan gelombang mikro kontroler.",
       "topik mata kuliah": "fungsi sistem gelombang mikro, prinsip kerja dan parameter.",
       "software": "-",
       "sesi mata kuliah": "09.50 - 11.30",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": null,
       "mata kuliah": "transmisi dan saluran informasi",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang pemahaman dan analisa pada grafik protokol jaringan.",
       "topik mata kuliah": "pemrosesan sinyal untuk komunikasi radio digital, jalur gelombang mikro.",
       "software": "wireshark",
       "sesi mata kuliah": "11.40 - 13.20",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": 1708030617,
       "mata kuliah": "sistem penunjang keputusan",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang pengambilan keputusan pada suatu kasus berbasis teknologi informasi.",
       "topik mata kuliah": "teknik – teknik pada sistem pendukung keputusan.",
       "software": "-",
       "sesi mata kuliah": "13.30 - 15.10",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": null,
       "mata kuliah": "text mining",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang dasar – dasar proses ekstraksi pola pada sejumlah sumber data tak terstruktur.",
       "topik mata kuliah": "konsep dan teknik data mining, text categorization dan  text clustering.",
       "software": "-",
       "sesi mata kuliah": "15.20 - 17.00",
       "mahasiswa mata kuliah": "alisa, berry, cho, dini, elvin, firman, gino, hilma.",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": null,
       "mata kuliah": "pengantar robotika",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi mengenai pengantar alat dan pemrograman robotika.",
       "topik mata kuliah": "pembuatan robot, jenis - jenis robot.",
       "software": "-",
       "sesi mata kuliah": "17.00 - 18.30",
       "mahasiswa mata kuliah": "ilysa, jenny, karil, lexi, muhammad, novin, omar, pras, qasir",
       "referensi mata kuliah": "-"
     },
     {
       "kode mata kuliah": null,
       "mata kuliah": "deep learning",
       "sks": 2,
       "semester": "ganjil",
       "informasi mata kuliah": "studi tentang pendalaman rangkaian metode jaringan syaraf tiruan dan pola dari suatu data.",
       "topik mata kuliah": "artificial neural network, regresi dan klasifikasi.",
       "software": "-",
       "sesi mata kuliah": "18.40 - 20.20",
       "mahasiswa mata kuliah": "rikza, salma, tiara, umairah, vina, wildan, xavier, yoga, zaskia.",
       "referensi mata kuliah": "https://drive.google.com/open?id=19n2w_uqfb7cvcp0aj0hei8cqdfatfdt-"
     }
        ] 
        dispatcher.utter_message("Silahkan di cek : ")
        description = ", ".join([c["mata kuliah"] for c in info_matkul])
        dispatcher.utter_message("{}".format(description))
        return [SlotSet("info_matkul", info_matkul)]

# %%
class ActionDefaultFallback(Action):
    def name(self):
        return "action_default_fallback"

    def run(self, dispatcher, tracker, domain):
        from rasa_core.events import UserUtteranceReverted

        dispatcher.utter_template("utter_salah", tracker, silent_fail=True)

        return [UserUtteranceReverted()]

# %%
#class ActionInfoMatkul(Action):
 #   def name(self):
  #      return "action_info_matkul"
    
   # def run(self, dispatcher, tracker, domain):
    #    dispatcher.utter_message(tracker.get_slot("info_matkul"))
     #   tracker.get_slot('matkul')
      #  with open('info_matkul.json') as json_file:  
       #     data = json.load(json_file)
        #    for p in data:
         #       print('Kode Mata Kuliah : ' + p['Kode Mata Kuliah'])
          #      print('Mata Kuliah : ' + p['Mata Kuliah'])
           #     print('SKS : ' + p['SKS'])
            #    print('Semester : ' + p['Semester'])
             #   print('Informasi Mata Kuliah : ' + p['Informasi Mata Kuliah'])
              #  print('Topik Mata Kuliah : ' + p['Topik Mata Kuliah'])
               # print('Software Mata Kuliah : ' + p['Software'])
                #print('Sesi Mata Kuliah : ' + p['Sesi Mata Kuliah'])
                #print('Mahasiswa Mata Kuliah : ' + p['Mahasiswa Mata Kuliah'])
                #print('Referensi Mata Kuliah : ' + p['Referensi Mata Kuliah'])
                #print('')               
        #return [SlotSet("info_matkul")]
